# %% [markdown]
# <a href="https://colab.research.google.com/github/bhavana2904/PES-IO/blob/main/Gold_Price_EDA.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
df=pd.read_csv("Gold Price.csv")

# %%
df.head
# Out:
# <bound method NDFrame.head of             Date  Price   Open   High    Low  Volume  Chg%
# 0     2014-01-01  29542  29435  29598  29340    2930  0.25
# 1     2014-01-02  29975  29678  30050  29678    3140  1.47
# 2     2014-01-03  29727  30031  30125  29539    3050 -0.83
# 3     2014-01-04  29279  29279  29279  29279       0 -1.51
# 4     2014-01-06  29119  29300  29395  29051   24380 -0.55
# ...          ...    ...    ...    ...    ...     ...   ...
# 2222  2022-08-01  51260  51899  51899  51023    1350 -0.20
# 2223  2022-08-02  51274  51438  51527  51100     230  0.03
# 2224  2022-08-03  51225  51250  51375  51137      70 -0.10
# 2225  2022-08-04  51802  51713  51903  51713      10  1.13
# 2226  2022-08-05  51820  51935  51965  51525   11080  0.03
#
# [2227 rows x 7 columns]>

# %%
df.tail
# Out:
# <bound method NDFrame.tail of             Date  Price   Open   High    Low  Volume  Chg%
# 0     2014-01-01  29542  29435  29598  29340    2930  0.25
# 1     2014-01-02  29975  29678  30050  29678    3140  1.47
# 2     2014-01-03  29727  30031  30125  29539    3050 -0.83
# 3     2014-01-04  29279  29279  29279  29279       0 -1.51
# 4     2014-01-06  29119  29300  29395  29051   24380 -0.55
# ...          ...    ...    ...    ...    ...     ...   ...
# 2222  2022-08-01  51260  51899  51899  51023    1350 -0.20
# 2223  2022-08-02  51274  51438  51527  51100     230  0.03
# 2224  2022-08-03  51225  51250  51375  51137      70 -0.10
# 2225  2022-08-04  51802  51713  51903  51713      10  1.13
# 2226  2022-08-05  51820  51935  51965  51525   11080  0.03
#
# [2227 rows x 7 columns]>

# %%
df.sample()
# Out:
#            Date  Price   Open   High    Low  Volume  Chg%
# 737  2016-10-21  29936  29835  29960  29800    7310  0.15

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2227 entries, 0 to 2226
# Data columns (total 7 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Date    2227 non-null   object
#  1   Price   2227 non-null   int64
#  2   Open    2227 non-null   int64
#  3   High    2227 non-null   int64
#  4   Low     2227 non-null   int64
#  5   Volume  2227 non-null   int64
#  6   Chg%    2227 non-null   float64
# dtypes: float64(1), int64(5), object(1)
# memory usage: 121.9+ KB

# %%
df.describe
# Out:
# <bound method NDFrame.describe of             Date  Price   Open   High    Low  Volume  Chg%
# 0     2014-01-01  29542  29435  29598  29340    2930  0.25
# 1     2014-01-02  29975  29678  30050  29678    3140  1.47
# 2     2014-01-03  29727  30031  30125  29539    3050 -0.83
# 3     2014-01-04  29279  29279  29279  29279       0 -1.51
# 4     2014-01-06  29119  29300  29395  29051   24380 -0.55
# ...          ...    ...    ...    ...    ...     ...   ...
# 2222  2022-08-01  51260  51899  51899  51023    1350 -0.20
# 2223  2022-08-02  51274  51438  51527  51100     230  0.03
# 2224  2022-08-03  51225  51250  51375  51137      70 -0.10
# 2225  2022-08-04  51802  51713  51903  51713      10  1.13
# 2226  2022-08-05  51820  51935  51965  51525   11080  0.03
#
# [2227 rows x 7 columns]>

# %%
df.shape
# Out:
# (2227, 7)

# %%
df.size
# Out:
# 15589

# %%
df.columns
# Out:
# Index(['Date', 'Price', 'Open', 'High', 'Low', 'Volume', 'Chg%'], dtype='object')

# %%
df.count
# Out:
# <bound method DataFrame.count of             Date  Price   Open   High    Low  Volume  Chg%
# 0     2014-01-01  29542  29435  29598  29340    2930  0.25
# 1     2014-01-02  29975  29678  30050  29678    3140  1.47
# 2     2014-01-03  29727  30031  30125  29539    3050 -0.83
# 3     2014-01-04  29279  29279  29279  29279       0 -1.51
# 4     2014-01-06  29119  29300  29395  29051   24380 -0.55
# ...          ...    ...    ...    ...    ...     ...   ...
# 2222  2022-08-01  51260  51899  51899  51023    1350 -0.20
# 2223  2022-08-02  51274  51438  51527  51100     230  0.03
# 2224  2022-08-03  51225  51250  51375  51137      70 -0.10
# 2225  2022-08-04  51802  51713  51903  51713      10  1.13
# 2226  2022-08-05  51820  51935  51965  51525   11080  0.03
#
# [2227 rows x 7 columns]>

# %%
df.isnull().sum()
# Out:
# Date      0
# Price     0
# Open      0
# High      0
# Low       0
# Volume    0
# Chg%      0
# dtype: int64

# %%
df.dtypes
# Out:
# Date       object
# Price       int64
# Open        int64
# High        int64
# Low         int64
# Volume      int64
# Chg%      float64
# dtype: object

# %%
df.nunique()
# Out:
# Date      2227
# Price     2056
# Open      1902
# High      1990
# Low       1958
# Volume    1455
# Chg%       407
# dtype: int64

# %%
df.nlargest(10,'Price')
# Out:
#             Date  Price   Open   High    Low  Volume  Chg%
# 1710  2020-08-06  56117  55405  56199  55400   45660  0.94
# 1709  2020-08-05  55597  54900  55949  54701      40  1.48
# 1712  2020-08-10  55243  54900  55660  54900   35600  0.41
# 1711  2020-08-07  55018  56351  56499  54925   53590 -1.96
# 1708  2020-08-04  54784  54094  54950  53641     110  1.59
# 2119  2022-03-08  54146  53467  55428  53340   51930  1.28
# 1707  2020-08-03  53927  53988  53988  53600     150  0.64
# 1718  2020-08-18  53738  53387  54180  51888   70760  0.57
# 1706  2020-07-31  53582  53999  54000  53210     670  1.12
# 2118  2022-03-07  53461  52558  53938  52558   32759  2.27

# %%
df.nsmallest(10,'Price')
# Out:
#            Date  Price   Open   High    Low  Volume  Chg%
# 425  2015-08-05  24545  24614  24635  24500     100 -0.38
# 424  2015-08-04  24638  24670  24704  24540     290 -0.23
# 415  2015-07-22  24688  24850  24850  24591   20050 -0.88
# 426  2015-08-06  24692  24583  24745  24530   10620  0.60
# 423  2015-08-03  24696  24823  24886  24666    2830 -0.38
# 417  2015-07-24  24729  24701  24829  24470   19480 -0.05
# 420  2015-07-29  24729  24784  24849  24705   14890 -0.16
# 421  2015-07-30  24739  24702  24824  24581   17050  0.04
# 416  2015-07-23  24742  24786  24919  24716   18270  0.22
# 520  2015-12-17  24766  25302  25302  24671   20770 -2.39

# %%
df.corr()
# Out:
# <ipython-input-17-2f6f6606aa2c>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.corr()
#            Price      Open      High       Low    Volume      Chg%
# Price   1.000000  0.999423  0.999681  0.999741  0.272479  0.032363
# Open    0.999423  1.000000  0.999693  0.999631  0.272942  0.003337
# High    0.999681  0.999693  1.000000  0.999481  0.278379  0.019092
# Low     0.999741  0.999631  0.999481  1.000000  0.266097  0.019264
# Volume  0.272479  0.272942  0.278379  0.266097  1.000000 -0.039056
# Chg%    0.032363  0.003337  0.019092  0.019264 -0.039056  1.000000

# %%
df.plot()
# Out:
# <Axes: >

# %%
import matplotlib.pyplot as plt

# %%
df.plot.box()
plt.boxplot(df['Price'])
plt.show()

# %%
df.plot.bar()
# Out:
# <Axes: >

# %%
df['Date']=pd.to_datetime(df['Date'])

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from collections import OrderedDict

# %%
start_date = '01/01/2018'
end_date = '12/31/2022'
mask = (df['Date'] >= start_date) & (df['Date'] <= end_date)
df_filtered = df.loc[mask]

monthly_sum = df_filtered.groupby(df_filtered['Date'].dt.strftime('%Y-%m'))['Price'].sum()

monthly_sum_dict = dict(monthly_sum)
monthly_sum_ordered = dict(OrderedDict(sorted(monthly_sum_dict.items())))

df_plot = pd.DataFrame(monthly_sum_ordered, index=['2018', '2019', '2020', '2021', '2022']).T
df_plot.plot(kind='bar', title='Monthly Sum of Price by Year')
# Out:
# <Axes: title={'center': 'Monthly Sum of Price by Year'}>

# %%
df.fillna(0, inplace=True)

plt.figure(figsize=(12, 6))
plt.bar(df['Date'], df['Price'], label='Price', width=20, alpha=0.7, color='b')
plt.bar(df['Date'], df['Volume'], label='Volume', width=20, alpha=0.7, color='g')

ax = plt.gca()
ax2 = ax.twinx()
ax2.bar(df['Date'], df['Chg%'], label='Change %', width=20, alpha=0.7, color='y')

plt.xlabel('Date')
plt.ylabel('Price and Volume')
ax2.set_ylabel('Open')
plt.title('Monthly Data from 2014 to 2023')
plt.xticks(rotation=45)

lines1, labels1 = ax.get_legend_handles_labels()
lines2, labels2 = ax2.get_legend_handles_labels()
ax2.legend(lines1 + lines2, labels1 + labels2, loc='upper right')

plt.grid(axis='y', linestyle='--', alpha=0.7)

plt.tight_layout()
plt.show()

# %%
result = adfuller(series, autolag='AIC')
print(f'ADF Statistic: {result[0]}')
print(f'n_lags: {result[1]}')
print(f'p-value: {result[1]}')
for key, value in result[4].items():
    print('Critial Values:')
    print(f'   {key}, {value}')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-9-79aa721e5561> in <cell line: 1>()
# ----> 1 result = adfuller(series, autolag='AIC')
#       2 print(f'ADF Statistic: {result[0]}')
#       3 print(f'n_lags: {result[1]}')
#       4 print(f'p-value: {result[1]}')
#       5 for key, value in result[4].items():
#
# NameError: name 'adfuller' is not defined

# %%
kpss_stat, p_value, lags, critical_values = sm.tsa.kpss(df['Price'], nlags='auto')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-10-705be5fb41a5> in <cell line: 1>()
# ----> 1 kpss_stat, p_value, lags, critical_values = sm.tsa.kpss(df['Price'], nlags='auto')
#
# NameError: name 'sm' is not defined

# %%
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf

# %%
fig, axes = plt.subplots(3, 2, sharex = True)
axes[0, 0].plot(df['Price'])
axes[0, 0].set_title('The Genuine Series')
plot_acf(df['Price'], ax = axes[0, 1]);

# %%
from statsmodels.tsa.arima.model import ARIMA
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf

#Prepare the data
dates = pd.to_datetime(df['Price'])
values =df['Price']
series = pd.Series(values.values, index=dates)

#Determine the optimal values for p and q using ACF and PACF plots
plot_acf(series)
plt.show()

plot_pacf(series)
plt.show()

#Grid search to find the optimal values for p, d, and q
best_aic = np.inf
best_order = None

for p in range(3):
    for d in range(2):
        for q in range(3):
            try:
                model = ARIMA(series, order=(p, d, q))
                model_fit = model.fit()
                aic = model_fit.aic

                if aic < best_aic:
                    best_aic = aic
                    best_order = (p, d, q)
            except:
                continue
print(f"Optimal (p, d, q) values: {best_order}")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-41-2c591889c5e1> in <cell line: 17>()
#      15
#      16 #Grid search to find the optimal values for p, d, and q
# ---> 17 best_aic = np.inf
#      18 best_order = None
#      19
#
# NameError: name 'np' is not defined

# %%
from statsmodels.tsa.arima.model import ARIMA

# Prepare the data
dates = pd.to_datetime(df['Price'])
values = df['Price']
series = pd.Series(values.values, index=dates)

# Fit the ARIMA model
order = (1,1,1)
model = ARIMA(df['Price'], order=order)
model_fit = model.fit()

print(model_fit.summary())
predictions = model_fit.predict()

# Forecast the next 39 values
forecast = model_fit.forecast(steps=39)

# Print the forecasted values
print(forecast)
# Out:
#                                SARIMAX Results
# ...
# Dep. Variable:                  Price   No. Observations:                 2227
# Model:                 ARIMA(1, 1, 1)   Log Likelihood              -16014.568
# Date:                Tue, 03 Oct 2023   AIC                          32035.137
# Time:                        10:41:07   BIC                          32052.261
# Sample:                             0   HQIC                         32041.390
#                                - 2227
# Covariance Type:                  opg
# ...
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1         -0.2253      0.327     -0.688      0.491      -0.867       0.416
# ma.L1          0.1893      0.331      0.573      0.567      -0.459       0.837
# sigma2      1.038e+05   1404.999     73.874      0.000    1.01e+05    1.07e+05
# ...

# %%
from sklearn.metrics import mean_absolute_error,mean_absolute_percentage_error,mean_squared_error, mean_absolute_error
mae = mean_absolute_error(df['Price'], predictions)
print("MAE:", mae)
mape = mean_absolute_percentage_error(df['Price'],predictions) * 100
print("MAPE:", mape)
#Plot the results
plt.figure(figsize=(20,6))
plt.plot(df['Price'], label='Actual',linewidth=8)
plt.plot(predictions, label='Predicted',linewidth=5)

plt.xlabel('Trend')
plt.ylabel('Value')
plt.title('ARIMA Model')
plt.legend()
plt.show()
# Out:
# MAE: 230.63443309282042
# MAPE: 0.651365217752077

# %%
def optimize_SARIMA(parameters_list, d, D, s, exog):

    results = []

    for param in tqdm_notebook(parameters_list):
        try:
            model = SARIMAX(exog, order=(param[0], d, param[1]), seasonal_order=(param[2], D, param[3], s)).fit(disp=-1)
        except:
            continue

        aic = model.aic
        results.append([param, aic])

    result_df = pd.DataFrame(results)
    result_df.columns = ['(p,q)x(P,Q)', 'AIC']
    #Sort in ascending order, lower AIC is better
    result_df = result_df.sort_values(by='AIC', ascending=True).reset_index(drop=True)

    return result_df

# %%
from itertools import product
import statsmodels.api as sm

# %%
p = range(0, 4, 1)
d = 1
q = range(0, 4, 1)
P = range(0, 4, 1)
D = 1
Q = range(0, 4, 1)
s = 4
parameters = product(p, q, P, Q)
parameters_list = list(parameters)
print(len(parameters_list))
# Out:
# 256

# %%
result_df = optimize_SARIMA(parameters_list, 1, 1, 4,df['Price'] )
result_df
best_model = SARIMAX(df['Price'], order=(0, 1, 1), seasonal_order=(3,1,3,4)).fit(dis=-1)
print(best_model.summary())
best_model.plot_diagnostics(figsize=(15,12));
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-45-ad107d9f5f28> in <cell line: 1>()
# ----> 1 result_df = optimize_SARIMA(parameters_list, 1, 1, 4,df['Price'] )
#       2 result_df
#       3 best_model = SARIMAX(df['Price'], order=(0, 1, 1), seasonal_order=(3,1,3,4)).fit(dis=-1)
#       4 print(best_model.summary())
#       5 best_model.plot_diagnostics(figsize=(15,12));
#
# <ipython-input-19-af3a6f313e7a> in optimize_SARIMA(parameters_list, d, D, s, exog)
#       3     results = []
#       4
# ----> 5     for param in tqdm_notebook(parameters_list):
#       6         try:
#       7             model = SARIMAX(exog, order=(param[0], d, param[1]), seasonal_order=(param[2], D, param[3], s)).fit(disp=-1)
#
# NameError: name 'tqdm_notebook' is not defined

# %%
import pandas as pd
from prophet import Prophet
from sklearn.metrics import mean_absolute_error,mean_absolute_percentage_error,mean_squared_error, mean_absolute_error, r2_score

#Rename the columns to 'ds' and 'y' for the time series data and target variable
#dftrainnew = dftrainnew.rename(columns={'Order Date': 'ds', 'Sales': 'y'})
dftrain = df.rename(columns={'Date': 'ds', 'Price':'y'})

#Initialize the Prophet model
model = Prophet(daily_seasonality=True)
model.add_seasonality(name='daily', period=24, fourier_order=3)  # Example: Weekly seasonality with period 7


#Fit the model to the data
model.fit(dftrain)

#Make predictions
forecast = model.predict()

actual_values = dftrain['y'].values
predicted_values = forecast['yhat'].values

# Print the forecasted values
print(forecast[['ds', 'yhat', 'yhat_lower', 'yhat_upper']])
# Out:
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp9mttkb3v/qapn1_fi.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp9mttkb3v/7ss1xlei.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=16051', 'data', 'file=/tmp/tmp9mttkb3v/qapn1_fi.json', 'init=/tmp/tmp9mttkb3v/7ss1xlei.json', 'output', 'file=/tmp/tmp9mttkb3v/prophet_modelzndj9yoa/prophet_model-20231004102423.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 10:24:23 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 10:24:25 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
#              ds          yhat    yhat_lower    yhat_upper
# 0    2014-01-01  29741.528190  28198.870361  31159.499422
# 1    2014-01-02  29743.014902  28290.595791  31108.928753
# ...

# %%
# Importing Libraries
import pandas as pd

df['Date'] = pd.to_datetime(df['Date'], format='%Y-%m-%d')
# plotting the time series data
df.plot(x='Date', y='Price', figsize=(20, 5), title='Gold Price')
# Out:
# <Axes: title={'center': 'Gold Price'}, xlabel='Date'>

# %%
# Seasonality decomposition
from statsmodels.tsa.seasonal import seasonal_decompose
from statsmodels.tsa.seasonal import seasonal_decompose
# holt winters
# single exponential smoothing
from statsmodels.tsa.holtwinters import SimpleExpSmoothing
# double and triple exponential smoothing
from statsmodels.tsa.holtwinters import ExponentialSmoothing

# %%
# Create a pandas series with the data
series=pd.Series(df['Price'])

# Perform Holt-Winters forecasting
model=ExponentialSmoothing(series, seasonal_periods=7, trend='add', seasonal='mul')
fit_model=model.fit()

# Forecast the next 36 values
forecast=fit_model.forecast(36)

# Print the forecasted values
print(forecast)
# Out:
# 2227    51795.903032
# 2228    51836.716380
# 2229    51864.623479
# 2230    51902.041232
# 2231    51851.904423
# 2232    51848.515845
# 2233    51808.564179
# 2234    51787.567812
# 2235    51828.374399
# 2236    51856.276816
# 2237    51893.688354
# 2238    51843.559423
# 2239    51840.171199
# 2240    51800.225771
# 2241    51779.232591
# 2242    51820.032419
# 2243    51847.930153
# 2244    51885.335477
# 2245    51835.214423
# 2246    51831.826552
# 2247    51791.887362
# 2248    51770.897370
# 2249    51811.690438
# 2250    51839.583489
# 2251    51876.982600
# 2252    51826.869423
# 2253    51823.481905
# 2254    51783.548954
# 2255    51762.562149
# 2256    51803.348458
# 2257    51831.236826
# 2258    51868.629723
# 2259    51818.524423
# 2260    51815.137259
# 2261    51775.210546
# 2262    51754.226929
# dtype: float64
# ...
