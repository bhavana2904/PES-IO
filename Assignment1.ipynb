# %% [markdown]
# <a href="https://colab.research.google.com/github/bhavana2904/PES-IO/blob/main/Assignment1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
df = pd.read_csv("monthly-beer-production-in-austr.csv")

# %%
df.describe()
# Out:
#        Monthly beer production
# count               476.000000
# mean                136.395378
# std                  33.738725
# min                  64.800000
# 25%                 112.900000
# 50%                 139.150000
# 75%                 158.825000
# max                 217.800000

# %%
df.nunique()
# Out:
# Month                      476
# Monthly beer production    383
# dtype: int64

# %%
df.isnull().sum()
# Out:
# Month                      0
# Monthly beer production    0
# dtype: int64

# %%
import numpy as np
import matplotlib.pyplot as plt

data = np.random.random(( 0 , 0 ))
plt.imshow( data )

plt.title( "2-D Heat Map" )
plt.show()
# Out:
# <ipython-input-9-4159a43fa89a>:5: UserWarning: Attempting to set identical low and high xlims makes transformation singular; automatically expanding.
#   plt.imshow( data )
# <ipython-input-9-4159a43fa89a>:5: UserWarning: Attempting to set identical low and high ylims makes transformation singular; automatically expanding.
#   plt.imshow( data )

# %%
df.plot.box()
plt.boxplot(df['Monthly beer production'])
plt.show()

# %%
data = [["1956-01",93.2],
["1956-02",96],
["1956-03",	95.2],
["1956-04",	77.1],
["1956-05",	70.9],
["1956-06",	64.8],
["1956-07",	70.1],
["1956-08",	77.3],
["1956-09",	79.5],
["1956-10",	100.6],
["1957-01",	95.9],
["1957-02",82.8],
["1957-03",83.3],
["1958-01",	96.3],
["1958-02",	84.4],
["1958-03",	91.2]   ]


df = pd.DataFrame(data, columns = ['Month', 'Monthly beer production'] )

df.plot.bar()

# plot between 2 attributes
plt.bar(df['Month'], df['Monthly beer production'])
plt.xlabel("Month")
plt.ylabel("Monthly beer production")
plt.show()

# %%
df['Month'] = pd.to_datetime(df['Month'])
df
# Out:
#         Month  Monthly beer production
# 0  1956-01-01                     93.2
# 1  1956-02-01                     96.0
# 2  1956-03-01                     95.2
# 3  1956-04-01                     77.1
# 4  1956-05-01                     70.9
# 5  1956-06-01                     64.8
# 6  1956-07-01                     70.1
# 7  1956-08-01                     77.3
# 8  1956-09-01                     79.5
# 9  1956-10-01                    100.6
# 10 1957-01-01                     95.9
# 11 1957-02-01                     82.8
# 12 1957-03-01                     83.3

# %%
start_date = '01/01/1956'
end_date='12/31/1956'
mask = (df['Month']>=start_date) & (df['Month']<=end_date)
df1956=df.loc[mask]
df1956
# Out:
#        Month  Monthly beer production
# 0 1956-01-01                     93.2
# 1 1956-02-01                     96.0
# 2 1956-03-01                     95.2
# 3 1956-04-01                     77.1
# 4 1956-05-01                     70.9
# 5 1956-06-01                     64.8
# 6 1956-07-01                     70.1
# 7 1956-08-01                     77.3
# 8 1956-09-01                     79.5
# 9 1956-10-01                    100.6

# %%
data = [["1956-01",93.2],
["1956-02",96],
["1956-03",	95.2],
["1956-04",	77.1],
["1956-05",	70.9],
["1956-06",	64.8],
["1956-07",	70.1],
["1956-08",	77.3],
["1956-09",	79.5],
["1956-10",	100.6],
["1957-01",	95.9],
["1957-02",82.8],
["1957-03",83.3],
["1958-01",	96.3],
["1958-02",	84.4],
["1958-03",	91.2]   ]
df.plot.bar()


plt.bar(df['Month'], df['Monthly beer production'])
plt.xlabel("Month")
plt.ylabel("Monthly beer production")
plt.show()
